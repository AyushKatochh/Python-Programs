# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushKatochh/Python-Programs/blob/main/regression_using_pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null

# %%
from pycaret.datasets import get_data
dataSets = get_data("index")
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# ...

# %%
data_1 = get_data("insurance")
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Initialize Setup
from pycaret.regression import *

#Perimeter setting for all classification models
s_model = setup(data = data_1, target="charges", silent=True)
# Out:
#                                Description             Value
# 0                               session_id              6073
# 1                                   Target           charges
# 2                            Original Data         (1338, 7)
# 3                           Missing Values             False
# 4                         Numeric Features                 2
# 5                     Categorical Features                 4
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (936, 14)
# 10                    Transformed Test Set         (402, 14)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
models()
# Out:
#                                        Name  ...  Turbo
# ID                                           ...
# lr                        Linear Regression  ...   True
# lasso                      Lasso Regression  ...   True
# ridge                      Ridge Regression  ...   True
# en                              Elastic Net  ...   True
# lar                  Least Angle Regression  ...   True
# llar           Lasso Least Angle Regression  ...   True
# omp             Orthogonal Matching Pursuit  ...   True
# br                           Bayesian Ridge  ...   True
# ard       Automatic Relevance Determination  ...  False
# par            Passive Aggressive Regressor  ...   True
# ransac              Random Sample Consensus  ...  False
# tr                       TheilSen Regressor  ...  False
# huber                       Huber Regressor  ...   True
# kr                             Kernel Ridge  ...  False
# svm               Support Vector Regression  ...  False
# ...

# %%
SVM = create_model('svm')
dt = create_model('dt')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     2901.0379  4.329257e+07  6579.7090  0.6552  0.6020  0.3147
# 1     3886.6099  4.947525e+07  7033.8644  0.6698  0.5992  0.4300
# 2     3066.9560  4.326773e+07  6577.8212  0.7493  0.4371  0.2710
# 3     3257.5450  4.184103e+07  6468.4643  0.7185  0.5357  0.3610
# 4     3592.3359  5.265668e+07  7256.4921  0.3866  0.5920  0.4845
# 5     2978.5770  3.540423e+07  5950.1457  0.7068  0.5098  0.4077
# 6     3580.7559  5.056673e+07  7111.0289  0.6986  0.5853  0.4118
# 7     2692.0913  3.651685e+07  6042.9173  0.6856  0.5060  0.3215
# 8     3280.7605  4.678216e+07  6839.7489  0.7355  0.5025  0.3028
# 9     2876.0425  4.135064e+07  6430.4465  0.5443  0.5961  0.4572
# Mean  3211.2712  4.411539e+07  6629.0638  0.6550  0.5466  0.3762
# SD     360.2674  5.461203e+06   413.4016  0.1046  0.0537  0.0685

# %%
best_model = compare_models()
# Out:
#                                     Model        MAE           MSE  \
# gbr           Gradient Boosting Regressor  2495.6856  2.083268e+07
# lightgbm  Light Gradient Boosting Machine  2786.2850  2.231333e+07
# rf                Random Forest Regressor  2605.2843  2.272268e+07
# ada                    AdaBoost Regressor  3869.1474  2.529047e+07
# et                  Extra Trees Regressor  2552.3130  2.588388e+07
# llar         Lasso Least Angle Regression  4195.8033  3.549299e+07
# ridge                    Ridge Regression  4211.2169  3.549851e+07
# br                         Bayesian Ridge  4209.6733  3.550307e+07
# lasso                    Lasso Regression  4203.8922  3.551113e+07
# lr                      Linear Regression  4204.6043  3.551520e+07
# lar                Least Angle Regression  4220.5563  3.563914e+07
# dt                Decision Tree Regressor  3211.2712  4.411539e+07
# huber                     Huber Regressor  3746.3182  5.005016e+07
# ...

# %%
#Plot the regression plot
plot_model(dt)

# %%
plot_model(dt, plot="error")
